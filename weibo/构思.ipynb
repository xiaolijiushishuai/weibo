# %%
代理表
id, 代理ip, 代理端口, 代理账号, 代理密码, 代理账号个数, 添加时间, 修改时间
账号类型表
id, 类型名称, 添加时间, 修改时间
账号表
id, 账号, 密码, 账号类型id, 代理id, 最后登录状态（成功，失败，异常）, 最后登录时间, 添加时间, 修改时间
文章类型表
id, 类型名称,状态（正常，删除）, 添加时间, 修改时间
文章表
id, 文章类型id, 文章内容, 文章状态（未发布，待发布，已发布）, 添加时间, 修改时间
评论表
id, 评论内容, 评论分组, 添加时间, 修改时间
文章发布日志表
id, 账号id, 文章id, 发布时间
任务表
id, 任务类型(点赞，评论，发布文章), 任务关联表id, 任务状态(未开始，开始，暂停，结束，删除), 任务名称, 添加时间, 修改时间
任务账号表
id, 账号名称, 账号头像, 账号uid, 添加时间, 修改时间
任务关联账号表
id, 任务账号id, 添加时间, 修改时间
点赞任务关联表
id, 用户id, 添加时间, 修改时间
评论任务关联表
id, 用户id, 评论id, 添加时间, 修改时间
发布文章任务关联表
id, 文章id, 添加时间, 修改时间
任务日志表
id, 操作账号id, 操作账号名称, 任务账号id, 任务账号名称, 任务类型, 执行时间
发布日志表
id, 文章id, 账号id, 发布时间, 添加时间, 修改时间
任务执行表
id, 任务id, 任务类型, 关联表id, 执行任务名称, 开始执行时间, 结束执行时间, 执行次数, 执行间隔时间, 操作间隔时间, 添加时间, 修改时间



问题
文章是否为纯文字,公开     暂时纯文字
文章发布完以后是否可修改    不可修改，只用一次
点赞用户如何指定，同一批用户是否会被多次点赞      指定账号昵称，搜索出来随机选择一个
评论任务是指评论指定用户的某个作品吗？评论内容是随机从评论库里面选择吗？具体指某个作品
代理配置问题      客户自己购买配置代理
执行任务的时候多选账号，然后多选文章，是随机发布一篇文章吗？不建议多选账号


添加代理（代理ip，代理端口，代理账号，代理密码）
添加账号（账号，密码，选择或输入账号类型，代理id可选）
添加文章（文章内容，选择或输入文章类型）
添加评论（评论内容，选择或输入评论类型）
添加任务
添加发布任务（选择发布账号（多选），选择发布文章（多选），任务名称）账号随机领取文章发布
添加点赞任务（选择点赞用户（多选），任务名称）
添加评论账户（选择评论账户，选择评论内容，任务名称）
添加关注任务（选择关注账户，任务名称）
执行任务（选择任务，选择执行账号id，执行时间，执行间隔，结束时间，执行任务名称）
修改代理（代理ip，代理端口，代理账号，代理密码）
修改账号（账号，密码，选择或输入账号类型，代理id可选）
修改任务
修改发布任务（选择发布账号（多选），选择发布文章（多选），任务名称）账号随机领取文章发布
修改点赞任务（选择点赞用户（多选），任务名称）
修改评论账户（选择评论账户，选择评论内容，任务名称）
修改关注任务（选择关注账户，任务名称）



当用户评论前3页出现n个相同评论时直接复制评论
发布任务随机
点赞评论点击到用户主页去随机选择两三个作品进行点赞评论

主要用来养号，过风控
